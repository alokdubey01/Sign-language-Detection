# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np
import json
import random
from keras.models import load_model

model = load_model('chatbot_model.h5')

intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
labels = pickle.load(open('labels.pkl','rb'))

# %%
#adding text to speech module
import pyttsx3
import speech_recognition as sr
engine = pyttsx3.init()
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)
engine.setProperty("rate", 150)

# %%
def takecommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        r.energy_threshold = 3000
        audio = r.listen(source)

    try:
        print("Recognizing...")
        response = r.recognize_google(audio, language='en-in')
        #response = r.recognize_google(audio, language='hi-In')
        print(f"User Said:{response}\n")

    except Exception as e:
        print("Say that again please...")
        speak("say that again please...")
        return "None"
    return response


def speak(audio):
    engine.say(audio)
    engine.runAndWait()

# %%
def bank_of_words(s,words, show_details=True):
    bag_of_words = [0 for _ in range(len(words))]
    sent_words = nltk.word_tokenize(s)
    sent_words = [lemmatizer.lemmatize(word.lower()) for word in sent_words]
    for sent in sent_words:
        for i,w in enumerate(words):
            if w == sent:
                bag_of_words[i] = 1
    return np.array(bag_of_words)

def predict_label(s, model):
    # filtering out predictions
    pred = bank_of_words(s, words,show_details=False)
    response = model.predict(np.array([pred]))[0]
    ERROR_THRESHOLD = 0.25
    final_results = [[i,r] for i,r in enumerate(response) if r>ERROR_THRESHOLD]
    final_results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in final_results:
        return_list.append({"intent": labels[r[0]], "probability": str(r[1])})
    return return_list

# %%
def Response(ints, intents_json):
    tags = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tags):
            response = random.choice(i['responses'])
            break
    return response

def chatbot_response(msg):
    ints = predict_label(msg, model)
    response = Response(ints, intents)
    return response

# %%
def chat():
    while True:
        #inp = input("You: ")
        inp = takecommand()
        #if inp.lower() == 'quit':
        #    break
        response = chatbot_response(inp)
        #print("\n BOT: " + response + '\n\n')
        speak(response)

chat()
# Out:
# Listening...
# Recognizing...
# result2:
# {   'alternative': [   {   'confidence': 0.57440978,
#                            'transcript': 'dhooram Banaya'},
#                        {'transcript': 'Dharam Banaya'},
#                        {'transcript': 'duram Banaya'},
#                        {'transcript': 'dooram Banaya'},
#                        {'transcript': 'Doraemon Banaya'}],
#     'final': True}
# User Said:dhooram Banaya
#
# 1/1 [==============================] - 0s 238ms/step
# Listening...
# Recognizing...
# result2:
# []
# Say that again please...
# 1/1 [==============================] - 0s 19ms/step
# Listening...
# Recognizing...
# result2:
# {   'alternative': [   {'confidence': 0.74248451, 'transcript': 'how are you'},
#                        {'transcript': 'how r u'},
#                        {'transcript': 'how are u'},
#                        {'transcript': 'how are you are'}],
#     'final': True}
# User Said:how are you
#
# 1/1 [==============================] - 0s 28ms/step
# Listening...
# Recognizing...
# result2:
# {   'alternative': [   {   'confidence': 0.88705796,
#                            'transcript': 'what can can what can do for me'},
#                        {'transcript': 'what can what can do for me'},
#                        {'transcript': 'what can can what can do you for me'},
#                        {'transcript': 'what can I can what can do for me'},
#                        {'transcript': 'what can I what can do for me'}],
#     'final': True}
# User Said:what can can what can do for me
#
# 1/1 [==============================] - 0s 18ms/step
# Listening...
# Recognizing...
# result2:
# {   'alternative': [   {   'confidence': 0.83728141,
#                            'transcript': 'can you can you can you also I think '
#                                          'for me'},
#                        {   'transcript': 'can you can can you also I think for '
#                                          'me'},
#                        {   'transcript': 'can you please can you also I think '
#                                          'for me'},
#                        {   'transcript': 'can you can you can also anything '
#                                          'for me'},
#                        {'transcript': 'can you can you also I think for me'}],
#     'final': True}
# User Said:can you can you can you also I think for me
#
# 1/1 [==============================] - 0s 22ms/step
# Listening...
# Recognizing...
# result2:
# []
# Say that again please...
# 1/1 [==============================] - 0s 32ms/step
# Listening...
# Recognizing...
# result2:
# {   'alternative': [   {   'confidence': 0.80337191,
#                            'transcript': 'how you could help me'},
#                        {'transcript': 'how are you could help me'},
#                        {'transcript': 'why you could help me'},
#                        {'transcript': 'hey you could help me'},
#                        {'transcript': 'hi you could help me'}],
#     'final': True}
# User Said:how you could help me
#
# 1/1 [==============================] - 0s 17ms/step
# Listening...
# Recognizing...
# result2:
# []
# Say that again please...
# 1/1 [==============================] - 0s 18ms/step
# Listening...
# Recognizing...
# result2:
# {   'alternative': [   {'confidence': 0.69453061, 'transcript': 'hi dear'},
#                        {'transcript': 'my dear'},
#                        {'transcript': 'pure'},
#                        {'transcript': 'had your'},
#                        {'transcript': 'hide your'}],
#     'final': True}
# User Said:hi dear
#
# 1/1 [==============================] - 0s 18ms/step
# Listening...
# Recognizing...
# result2:
# {   'alternative': [   {   'confidence': 0.92995483,
#                            'transcript': 'see you later'},
#                        {'transcript': 'Shiv letter'},
#                        {'transcript': 'see you letter'},
#                        {'transcript': 'Shiv Leta'},
#                        {'transcript': 'C letter'}],
#     'final': True}
# User Said:see you later
#
# 1/1 [==============================] - 0s 18ms/step
# Listening...
# Recognizing...
# result2:
# {   'alternative': [   {'confidence': 0.52795243, 'transcript': 'goodbye'},
#                        {'transcript': 'good bye'},
#                        {'transcript': 'good boy'},
#                        {'transcript': 'good by'},
#                        {'transcript': 'gud bye'}],
#     'final': True}
# User Said:goodbye
#
# 1/1 [==============================] - 0s 18ms/step
# Listening...
# Recognizing...
# result2:
# []
# Say that again please...
# 1/1 [==============================] - 0s 33ms/step
# Listening...
# Recognizing...
# result2:
# []
# Say that again please...
# 1/1 [==============================] - 0s 20ms/step
# Listening...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 11
#       8         #print("\n BOT: " + response + '\n\n')
#       9         speak(response)
# ---> 11 chat()
#
# Cell In[6], line 4, in chat()
#       1 def chat():
#       2     while True:
#       3         #inp = input("You: ")
# ----> 4         inp = takecommand()
#       5         #if inp.lower() == 'quit':
#       6         #    break
#       7         response = chatbot_response(inp)
#
# Cell In[3], line 7, in takecommand()
#       5     r.pause_threshold = 1
#       6     r.energy_threshold = 3000
# ----> 7     audio = r.listen(source)
#       9 try:
#      10     print("Recognizing...")
#
# File ~\Dropbox\Desktop\Jupyter\Machine Learning\venv\lib\site-packages\speech_recognition\__init__.py:709, in Recognizer.listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     706 if phrase_time_limit and elapsed_time - phrase_start_time > phrase_time_limit:
#     707     break
# --> 709 buffer = source.stream.read(source.CHUNK)
#     710 if len(buffer) == 0: break  # reached end of the stream
#     711 frames.append(buffer)
#
# File ~\Dropbox\Desktop\Jupyter\Machine Learning\venv\lib\site-packages\speech_recognition\__init__.py:211, in Microphone.MicrophoneStream.read(self, size)
#     210 def read(self, size):
# --> 211     return self.pyaudio_stream.read(size, exception_on_overflow=False)
#
# File ~\Dropbox\Desktop\Jupyter\Machine Learning\venv\lib\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:
